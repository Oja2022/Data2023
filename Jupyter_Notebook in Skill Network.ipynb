# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio
# ## __My name is Ojas Pradeep Dhamapurkar__
# I am currently working as a Process Engineer and aspire to be a Data Scientist
# _I am interested in Data Science because it allows us to handle huge amount of data and get insights from it which will help in the industry and current field I am working in to prevent any hazard in the future._
# ###   My code takes user information like Name, Occupation and Why they are interested in Data Science as input and gives it as output.

# %%
name= input("What is your Name?\n")
print("Hello " + name)
Occupation= input("What is your Occupation?\n")
print("So your Occupation is " + Occupation)
Data_Science= input("Why are you interersted in Data Science?\n")
print(Data_Science + " Good and Best wishes to you.")

# %% [markdown]
# ***The above code shows the following information
# 1. Name of the Person
# 2. Occupation of the Person
# 3. Whys is he/she interested in data science
# - Note that we have to enter the information correctly for it to be printed.
